# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import math
import matplotlib.gridspec as gridspec
from matplotlib import ticker
plt.rcParams['axes.unicode_minus']=False

# %%
x = 7*np.pi/36
print(np.sin(np.pi/2 - x))
print(np.cos(x))
print(np.cos(x + np.pi/2))
print(np.sin(x))
# Out:
# 0.8191520442889918
# 0.8191520442889918
# -0.5735764363510462
# 0.573576436351046

# %%
width_bot_elec = 200 #nn
width_top_elec = 200 #nm
dist_cruc = 650 #mm
origin_trans = 62.5 #mm  This is the distance by which the origin of the wafer gets translated when tilted, because tilt axis is not in wafer plane
radius_wafer = 50 #mm
heigt_resist_bot = 200 #nm
height_resist_top = 600 #nm
bot_electrode = 35 #nm
top_electrode = 75 #nm
offset = 25 # nm
tilt = 7*np.pi/36 # alpha in model in radians 
dist_cruc_actual = abs(dist_cruc*np.cos(tilt) - origin_trans)

# crucible vector C = (0, -D_cruc*sin(alpha), D_actual)
# r = (x,y,0)

x =  np.linspace(-radius_wafer, radius_wafer, num=100)
y =  np.linspace(-radius_wafer, radius_wafer, num=100)

x_surf, y_surf = np.meshgrid(x, y)

# %%
fig, ax = plt.subplots()
area_simple = np.outer((width_bot_elec + offset - height_resist_top*abs(x)/dist_cruc_actual),(width_top_elec + offset  - height_resist_top*abs(y)/dist_cruc_actual))
# print(height_resist_top*theta)
plot_simple = ax.contourf(x_surf,y_surf,area_simple/10**6, 5, cmap='jet')
cbar = fig.colorbar(plot_simple)

# %%
# Formula Tb' = Tb*((D_cruc - R)^2*D_actual)/|r - C|^3
# use numpy np.linalg.norm() for calculating magnitude of vector

# %%
r = [x,y,0]
C = [0, -dist_cruc*np.sin(tilt), dist_cruc_actual]

vec_r = np.array(r, dtype=object)
vec_C = np.array(C, dtype=object)
f = np.linalg.norm(vec_r - vec_C) # vector magnitude
num = ((dist_cruc - origin_trans)**2*dist_cruc_actual)/f**3
thick_bot_elec_real = bot_electrode*num

# %% [markdown]
# Sidewall contribution

# %%
# A_overlap =  W'x + 2Tb'*W'y
fig, ax = plt.subplots()
area_sidewall = np.outer((width_bot_elec + offset - height_resist_top*abs(x)/dist_cruc_actual + 2*thick_bot_elec_real),
                         (width_top_elec + offset  - height_resist_top*abs(y)/dist_cruc_actual))
plot_sidewall = ax.contourf(x_surf,y_surf,area_sidewall/10**6, 5, cmap='jet')
cbar = fig.colorbar(plot_sidewall)

# %% [markdown]
# Narrow top

# %%
fig, ax = plt.subplots()
narrow_top = (-bot_electrode*(dist_cruc - origin_trans)**2*(y + dist_cruc_actual*np.sin(tilt)))/f**3
area_narrowtop = np.outer((width_bot_elec + offset - height_resist_top*abs(x)/dist_cruc_actual + 2*thick_bot_elec_real),
                         (width_top_elec + offset  - height_resist_top*abs(y)/dist_cruc_actual) + narrow_top)
plot_narrowtop = ax.contourf(x_surf,y_surf,area_narrowtop/10**6, 5, cmap='jet')
cbar = fig.colorbar(plot_narrowtop)

# %%
distance = np.sqrt((x_surf**2+y_surf**2))
# area_simple = np.ma.masked_where(distance > 50, area_simple)
# area_total = np.ma.masked_where(distance > 50, area_total)
norm_conductance = 1 # S/nm2

masked_simple =  np.ma.masked_where(distance > 50, area_simple )
masked_sidewall =  np.ma.masked_where(distance > 50, area_sidewall )
masked_narrowtop = np.ma.masked_where(distance > 50, area_narrowtop) 

isn_simple = np.isnan(masked_simple)
isn_sidewall = np.isnan(masked_sidewall)
isn_narrowtop = np.isnan(masked_narrowtop)

norm_simple_dropna = masked_simple[~isn_simple]
norm_sidewall_dropna = masked_sidewall[~isn_sidewall]
norm_narrowtop_dropna = masked_narrowtop[~isn_narrowtop]

norm_simple = masked_simple/np.average(masked_simple)
norm_sidewall = masked_sidewall/np.average(masked_sidewall)
norm_narrowtop = masked_narrowtop/np.average(masked_narrowtop)

# %%
fig, ax = plt.subplots(figsize=(4,4),  sharex = False, sharey = False, constrained_layout = True)
levels = np.linspace(0.7,1.3,25)
plot_simple = ax.contourf(x_surf, y_surf, norm_simple, levels=levels,cmap = 'jet')
ax.plot(radius_wafer*np.cos(np.linspace(0,2*np.pi,100)),radius_wafer*np.sin(np.linspace(0,2*np.pi,100)),linewidth=1,color='black')
plt.yticks(np.arange((-radius_wafer), (radius_wafer +1), radius_wafer))
plt.xticks(np.arange((-radius_wafer), (radius_wafer +1), radius_wafer))
ax.tick_params(axis='x', labelsize=30, length = 5, pad = 10, colors='k', direction = 'in')
ax.tick_params(axis='y', labelsize=30, length = 5, pad = 10, colors='k', direction = 'in')
ax.set_aspect('equal')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
# cbar_axis_simple = fig.add_axes([1.05, 0.25, 0.05, 0.6])
# cbar_simple = fig.colorbar(plot_simple, cbar_axis_simple)
# cticks = cbar_simple.ax.get_yticklabels()
# cbar_simple.ax.set_yticklabels(cticks, fontsize=30)

paper_path = r'C:\Users\nmuthusubraman\Documents\GitHub\Paper_22_JJWaferScaleFab\TeX\figures\subplots\\'
# fig.subplots_adjust(left=0.05,right=0.85)
plt.savefig(paper_path + 'Geometric model eq1.pdf', dpi=500, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(4,4),  sharex = False, sharey = False, constrained_layout = True)
plot_sidewall = ax.contourf(x_surf, y_surf, norm_sidewall, 15, cmap = 'jet', levels=levels)
ax.plot(radius_wafer*np.cos(np.linspace(0,2*np.pi,100)),radius_wafer*np.sin(np.linspace(0,2*np.pi,100)),linewidth=1,color='black')
plt.yticks(np.arange((-radius_wafer), (radius_wafer +1), radius_wafer))
plt.xticks(np.arange((-radius_wafer), (radius_wafer +1), radius_wafer))
ax.tick_params(axis='x', labelsize=30, length = 5, pad = 10, colors='k', direction = 'in')
ax.tick_params(axis='y', labelsize=30, length = 5, pad = 10, colors='k', direction = 'in')
ax.set_aspect('equal')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
# cbar_axis_sidewall = fig.add_axes([1.05, 0.6, 0.04, 0.3])
# cbar_sidewall = fig.colorbar(plot_sidewall, cbar_axis_sidewall)
# cticks = cbar.ax.get_yticklabels()
plt.savefig(paper_path + 'Geometric model eq2.pdf', dpi=500, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(8,8),  sharex = False, sharey = False, constrained_layout = True)
levels = np.linspace(0.7,1.3,25)
plot_narrowtop = ax.contourf(x_surf, y_surf, norm_narrowtop, cmap = 'jet', levels=levels)
ax.plot(radius_wafer*np.cos(np.linspace(0,2*np.pi,100)),radius_wafer*np.sin(np.linspace(0,2*np.pi,100)),linewidth=1,color='black')
plt.yticks(np.arange((-radius_wafer), (radius_wafer +1), radius_wafer/2))
plt.xticks(np.arange((-radius_wafer), (radius_wafer +1), radius_wafer/2))
ax.tick_params(axis='x', labelsize=30, length = 5, pad = 10, colors='k', direction = 'in')
ax.tick_params(axis='y', labelsize=30, length = 5, pad = 10, colors='k', direction = 'in')
ax.set_aspect('equal')
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')
cbar_axis_narrowtop = fig.add_axes([1.1, 0.2, 0.05, 1])
cbar_narrowtop = fig.colorbar(plot_narrowtop, cbar_axis_narrowtop)
cticks = cbar_narrowtop.ax.get_yticklabels()
cbar_narrowtop.ax.set_yticklabels(cticks, fontsize=30)
cbar_narrowtop.ax.set_yticklabels(["{:.2f}".format(i) for i in cbar_narrowtop.get_ticks()], fontsize=30)
cbar_narrowtop.ax.locator_params(nbins=5)
cbar_narrowtop.set_label('Normalized conductance (G/$\mathrm{\mu}_G)$', rotation=90,labelpad=10,fontsize=30) 
plt.savefig(paper_path + 'Geometric model eq3.pdf', dpi=500, bbox_inches='tight')
